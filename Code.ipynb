# %% [markdown]
# # Preparing our dataset

# %%
import pandas as pd

# Read in track metadata with genre labels
tracks = pd.read_csv("fma-rock-vs-hiphop.csv" )

#inspect the  dataframe
tracks.info()
tracks.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17734 entries, 0 to 17733
# Data columns (total 21 columns):
# track_id         17734 non-null int64
# bit_rate         17734 non-null int64
# comments         17734 non-null int64
# composer         166 non-null object
# date_created     17734 non-null object
# date_recorded    1898 non-null object
# duration         17734 non-null int64
# favorites        17734 non-null int64
# genre_top        17734 non-null object
# genres           17734 non-null object
# genres_all       17734 non-null object
# information      482 non-null object
# interest         17734 non-null int64
# language_code    4089 non-null object
# license          17714 non-null object
# listens          17734 non-null int64
# lyricist         53 non-null object
# number           17734 non-null int64
# publisher        52 non-null object
# tags             17734 non-null object
# title            17734 non-null object
# dtypes: int64(8), object(13)
# memory usage: 2.8+ MB
#             track_id       bit_rate      comments      duration     favorites  \
# count   17734.000000   17734.000000  17734.000000  17734.000000  17734.000000
# mean    69394.145991  258971.413781      0.020695    220.942934      1.685237
# std     45784.589753   61535.621463      0.270070    177.906821      6.629402
# min         2.000000      -1.000000      0.000000      2.000000      0.000000
# 25%     29979.000000  220982.000000      0.000000    139.000000      0.000000
# 50%     64193.500000  256000.000000      0.000000    192.000000      1.000000
# 75%    109442.750000  320000.000000      0.000000    255.000000      2.000000
# max    155319.000000  448000.000000     24.000000   3675.000000    554.000000
#
#            interest        listens        number
# count  1.773400e+04   17734.000000  17734.000000
# mean   1.678238e+03    1079.709541      6.184110
# std    9.394969e+03    4693.497635      7.075062
# min    1.800000e+01       9.000000      0.000000
# 25%    4.210000e+02     214.000000      2.000000
# 50%    8.240000e+02     461.000000      5.000000
# 75%    1.628000e+03    1018.000000      8.000000
# max    1.038669e+06  433992.000000    100.000000

# %%
tracks.head(5)
# Out:
#    track_id  bit_rate  comments        composer         date_created  \
# 0       135    256000         1             NaN  2008-11-26 01:43:26
# 1       136    256000         1             NaN  2008-11-26 01:43:35
# 2       151    192000         0             NaN  2008-11-26 01:44:55
# 3       152    192000         0             NaN  2008-11-26 01:44:58
# 4       153    256000         0  Arc and Sender  2008-11-26 01:45:00
#
#          date_recorded  duration  favorites genre_top    genres  \
# 0  2008-11-26 00:00:00       837          0      Rock  [45, 58]
# 1  2008-11-26 00:00:00       509          0      Rock  [45, 58]
# 2                  NaN       192          0      Rock      [25]
# 3                  NaN       193          0      Rock      [25]
# 4  2008-11-26 00:00:00       405          5      Rock      [26]
#
#               ...             information interest  language_code  \
# 0             ...                     NaN     2484             en
# 1             ...                     NaN     1948             en
# 2             ...                     NaN      701             en
# 3             ...                     NaN      637             en
# 4             ...                     NaN      354             en
#
#                                              license listens  lyricist number  \
# 0  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1832       NaN      0
# 1  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1498       NaN      0
# 2  Attribution-NonCommercial-ShareAlike 3.0 Inter...     148       NaN      4
# 3  Attribution-NonCommercial-ShareAlike 3.0 Inter...      98       NaN     11
# 4  Attribution-NonCommercial-NoDerivatives (aka M...     424       NaN      2
#
#    publisher tags                       title
# 0        NaN   []                Father's Day
# 1        NaN   []  Peel Back The Mountain Sky
# 2        NaN   []                 Untitled 04
# 3        NaN   []                 Untitled 11
# 4        NaN   []          Hundred-Year Flood
#
# [5 rows x 21 columns]

# %%
# Read in track metrics with the features
echonest_metrics = pd.read_json("echonest-metrics.json", precise_float=True)

# Inspect the  dataframe
echonest_metrics.info()
echonest_metrics.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13129 entries, 0 to 9999
# Data columns (total 9 columns):
# acousticness        13129 non-null float64
# danceability        13129 non-null float64
# energy              13129 non-null float64
# instrumentalness    13129 non-null float64
# liveness            13129 non-null float64
# speechiness         13129 non-null float64
# tempo               13129 non-null float64
# track_id            13129 non-null int64
# valence             13129 non-null float64
# dtypes: float64(8), int64(1)
# memory usage: 1.0 MB
#        acousticness  danceability        energy  instrumentalness  \
# count  1.312900e+04  13129.000000  13129.000000      13129.000000
# mean   5.246876e-01      0.487290      0.537516          0.640536
# std    3.837186e-01      0.190148      0.278049          0.361430
# min    9.035000e-07      0.051307      0.000020          0.000000
# 25%    1.037726e-01      0.344759      0.321300          0.323466
# 50%    5.739848e-01      0.485635      0.549113          0.838134
# 75%    9.207270e-01      0.629094      0.776254          0.918244
# max    9.957965e-01      0.968645      0.999964          0.998016
#
#            liveness   speechiness         tempo       track_id       valence
# count  13129.000000  13129.000000  13129.000000   13129.000000  13129.000000
# mean       0.187804      0.099174    123.080061   34031.058268      0.439761
# std        0.158051      0.137381     35.015137   28950.422182      0.276028
# min        0.025297      0.022324     12.753000       2.000000      0.000010
# 25%        0.101406      0.036932     95.967000   12986.000000      0.197321
# 50%        0.119002      0.049019    120.057000   28097.000000      0.417743
# 75%        0.211041      0.085452    145.318000   45021.000000      0.665575
# max        0.980330      0.966177    251.072000  124911.000000      0.999990

# %%
echonest_metrics.head(5)
# Out:
#       acousticness  danceability    energy  instrumentalness  liveness  \
# 0         0.416675      0.675894  0.634476          0.010628  0.177647
# 1         0.374408      0.528643  0.817461          0.001851  0.105880
# 10        0.235506      0.438672  0.487752          0.716122  0.070359
# 100       0.977282      0.468808  0.134975          0.687700  0.105381
# 1000      0.081256      0.897197  0.367886          0.104474  0.085845
#
#       speechiness    tempo  track_id   valence
# 0        0.159310  165.922         2  0.576661
# 1        0.461818  126.957         3  0.269240
# 10       0.047298  120.790       145  0.650452
# 100      0.073124  119.646       341  0.430707
# 1000     0.041271  100.744      3457  0.749293

# %%
# Merge the relevant columns of tracks and echonest_metrics
echo_tracks = echonest_metrics.merge(tracks[['track_id', 'genre_top']], on='track_id')

# Inspect the resultant dataframe
echo_tracks.info()
echo_tracks.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
# acousticness        4802 non-null float64
# danceability        4802 non-null float64
# energy              4802 non-null float64
# instrumentalness    4802 non-null float64
# liveness            4802 non-null float64
# speechiness         4802 non-null float64
# tempo               4802 non-null float64
# track_id            4802 non-null int64
# valence             4802 non-null float64
# genre_top           4802 non-null object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB
#        acousticness  danceability       energy  instrumentalness     liveness  \
# count  4.802000e+03   4802.000000  4802.000000       4802.000000  4802.000000
# mean   4.870600e-01      0.436556     0.625126          0.604096     0.187997
# std    3.681396e-01      0.183502     0.244051          0.376487     0.150562
# min    9.491000e-07      0.051307     0.000279          0.000000     0.025297
# 25%    8.351236e-02      0.296047     0.450757          0.164972     0.104052
# 50%    5.156888e-01      0.419447     0.648374          0.808752     0.123080
# 75%    8.555765e-01      0.565339     0.837016          0.915472     0.215151
# max    9.957965e-01      0.961871     0.999768          0.993134     0.971392
#
#        speechiness        tempo       track_id      valence
# count  4802.000000  4802.000000    4802.000000  4802.000000
# mean      0.104877   126.687944   30164.871720     0.453413
# std       0.145934    34.002473   28592.013796     0.266632
# min       0.023234    29.093000       2.000000     0.014392
# 25%       0.036897    98.000750    7494.250000     0.224617
# 50%       0.049594   124.625500   20723.500000     0.446240
# 75%       0.088290   151.450000   44240.750000     0.666914
# max       0.966177   250.059000  124722.000000     0.983649

# %% [markdown]
# ## Pairwise relationships between continuous variables

# %%
#Create a correlation matrix
corr_metrics = echo_tracks.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_2f522736_2af2_11e9_a1b6_8c859073ade6row0_col0 {
#             background-color:  #023858;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row0_col1 {
#             background-color:  #e0dded;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row0_col2 {
#             background-color:  #fff7fb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row0_col3 {
#             background-color:  #97b7d7;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row0_col4 {
#             background-color:  #f3edf5;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row0_col5 {
#             background-color:  #b8c6e0;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row0_col6 {
#             background-color:  #e1dfed;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row0_col7 {
#             background-color:  #fff7fb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row0_col8 {
#             background-color:  #e2dfee;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row1_col0 {
#             background-color:  #d0d1e6;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row1_col1 {
#             background-color:  #023858;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row1_col2 {
#             background-color:  #fbf3f9;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row1_col3 {
#             background-color:  #f3edf5;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row1_col4 {
#             background-color:  #fff7fb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row1_col5 {
#             background-color:  #80aed2;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row1_col6 {
#             background-color:  #fff7fb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row1_col7 {
#             background-color:  #bdc8e1;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row1_col8 {
#             background-color:  #529bc7;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row2_col0 {
#             background-color:  #f5eff6;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row2_col1 {
#             background-color:  #fef6fa;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row2_col2 {
#             background-color:  #023858;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row2_col3 {
#             background-color:  #c4cbe3;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row2_col4 {
#             background-color:  #dcdaeb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row2_col5 {
#             background-color:  #dedcec;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row2_col6 {
#             background-color:  #adc1dd;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row2_col7 {
#             background-color:  #a7bddb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row2_col8 {
#             background-color:  #d9d8ea;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row3_col0 {
#             background-color:  #97b7d7;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row3_col1 {
#             background-color:  #fff7fb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row3_col2 {
#             background-color:  #d2d3e7;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row3_col3 {
#             background-color:  #023858;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row3_col4 {
#             background-color:  #fdf5fa;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row3_col5 {
#             background-color:  #fff7fb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row3_col6 {
#             background-color:  #d9d8ea;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row3_col7 {
#             background-color:  #f4eef6;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row3_col8 {
#             background-color:  #fff7fb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row4_col0 {
#             background-color:  #ced0e6;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row4_col1 {
#             background-color:  #ede8f3;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row4_col2 {
#             background-color:  #bdc8e1;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row4_col3 {
#             background-color:  #dbdaeb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row4_col4 {
#             background-color:  #023858;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row4_col5 {
#             background-color:  #c0c9e2;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row4_col6 {
#             background-color:  #dcdaeb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row4_col7 {
#             background-color:  #bdc8e1;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row4_col8 {
#             background-color:  #e8e4f0;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row5_col0 {
#             background-color:  #b8c6e0;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row5_col1 {
#             background-color:  #93b5d6;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row5_col2 {
#             background-color:  #eae6f1;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row5_col3 {
#             background-color:  #fff7fb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row5_col4 {
#             background-color:  #eae6f1;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row5_col5 {
#             background-color:  #023858;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row5_col6 {
#             background-color:  #dbdaeb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row5_col7 {
#             background-color:  #d0d1e6;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row5_col8 {
#             background-color:  #bfc9e1;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row6_col0 {
#             background-color:  #d0d1e6;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row6_col1 {
#             background-color:  #fef6fa;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row6_col2 {
#             background-color:  #a7bddb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row6_col3 {
#             background-color:  #c5cce3;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row6_col4 {
#             background-color:  #f0eaf4;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row6_col5 {
#             background-color:  #c8cde4;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row6_col6 {
#             background-color:  #023858;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row6_col7 {
#             background-color:  #d0d1e6;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row6_col8 {
#             background-color:  #d6d6e9;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row7_col0 {
#             background-color:  #fff7fb;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row7_col1 {
#             background-color:  #d2d2e7;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row7_col2 {
#             background-color:  #b5c4df;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row7_col3 {
#             background-color:  #f5eef6;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row7_col4 {
#             background-color:  #e9e5f1;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row7_col5 {
#             background-color:  #d1d2e6;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row7_col6 {
#             background-color:  #e1dfed;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row7_col7 {
#             background-color:  #023858;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row7_col8 {
#             background-color:  #dedcec;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row8_col0 {
#             background-color:  #cdd0e5;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row8_col1 {
#             background-color:  #4c99c5;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row8_col2 {
#             background-color:  #d1d2e6;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row8_col3 {
#             background-color:  #efe9f3;
#         }    #T_2f522736_2af2_11e9_a1b6_8c859073ade6row8_col4 {
#             bac

# %% [markdown]
# ## Normalizing the feature data

# %%
# Define features 
features = echo_tracks.drop(columns=['genre_top', 'track_id'])

# Define labels
labels = echo_tracks["genre_top"]

# Import the StandardScaler
from sklearn.preprocessing import StandardScaler

# Scale the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)
print(labels.head(5))
# Out:
# 0    Hip-Hop
# 1    Hip-Hop
# 2       Rock
# 3       Rock
# 4       Rock
# Name: genre_top, dtype: object

# %% [markdown]
# ## Principal Component Analysis on our scaled data

# %%
# This is just to make plots appear in the notebook
# %matplotlib inline

# Import  plotting module, and PCA class
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Get the explained variance ratios from PCA using all features
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_

print("Explained variance ratio : \n{}".format(pca.explained_variance_ratio_))
print("\n")
print("Number of components = {}".format(pca.n_components_))

# To plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(8), exp_variance )
ax.set_xlabel('Principal Component #')
ax.set_ylabel('Explained variance')
# Out:
# Explained variance ratio :
# [0.24297674 0.18044316 0.13650309 0.12994089 0.11056248 0.08302245
#  0.06923783 0.04731336]
#
#
# Number of components = 8
# Text(0,0.5,'Explained variance')

# %% [markdown]
# ## Further visualization of PCA

# %%
# Import numpy
import numpy as np

# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)

# Plot the cumulative explained variance and draw a dashed line at 0.90.
fig, ax = plt.subplots()
ax.plot(range(8), exp_variance)
ax.axhline(y=0.9, linestyle='--')
ax.set_xlabel('Principal Component #')
#ax.set_ylabel('Cumulative Explained variance')

n_components = 6

# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components, random_state=18)
pca.fit(scaled_train_features)
pca_projection = pca.transform(scaled_train_features)

# %% [markdown]
# ## Train a decision tree to classify genre

# %%
# Import train_test_split function and Decision tree classifier
from sklearn.model_selection import train_test_split

# Split our data
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, labels, random_state=18)

from sklearn.tree import DecisionTreeClassifier

# Train our decision tree
tree = DecisionTreeClassifier( random_state = 18)
tree.fit(train_features, train_labels)

# Predict the labels for the test data
pred_labels_tree = tree.predict(test_features) 

# Classification report
from sklearn.metrics import classification_report
class_rep_tree = classification_report(test_labels, pred_labels_tree)
print("Decision Tree: \n", class_rep_tree)
# Out:
# Decision Tree:
#               precision    recall  f1-score   support
#
#     Hip-Hop       0.64      0.58      0.61       245
#        Rock       0.90      0.91      0.90       956
#
# avg / total       0.84      0.85      0.84      1201

# %% [markdown]
# ## Compare our decision tree to a logistic regression

# %%
# Import LogisticRegression
from sklearn.linear_model import LogisticRegression


# Train our logistic regression and predict labels for the test set
logreg = LogisticRegression(random_state = 18)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Create the classification report for both models
from sklearn.metrics import classification_report
class_rep_tree = classification_report(test_labels, pred_labels_tree)
class_rep_log = classification_report(test_labels, pred_labels_logit)

print("Decision Tree: \n", class_rep_tree)
print("Logistic Regression: \n", class_rep_log)
# Out:
# Decision Tree:
#               precision    recall  f1-score   support
#
#     Hip-Hop       0.64      0.58      0.61       245
#        Rock       0.90      0.91      0.90       956
#
# avg / total       0.84      0.85      0.84      1201
#
# Logistic Regression:
#               precision    recall  f1-score   support
#
#     Hip-Hop       0.78      0.49      0.60       245
#        Rock       0.88      0.97      0.92       956
#
# avg / total       0.86      0.87      0.86      1201

# %% [markdown]
# ## Balance our data for greater performance

# %%
# Subset only the hip-hop tracks, and then only the rock tracks
hop_only = echo_tracks.loc[echo_tracks["genre_top"] == "Hip-Hop"]
rock_only = echo_tracks.loc[echo_tracks["genre_top"] == "Rock"]

# sample the rocks songs to be the same number as there are hip-hop songs
rock_only = rock_only.sample(len(hop_only), random_state=18)

# concatenate the dataframes rock_only and hop_only
rock_hop_bal = pd.concat([rock_only, hop_only])

# The features, labels, and pca projection are created for the balanced dataframe
features = rock_hop_bal.drop(['genre_top', 'track_id'], axis=1) 
labels = rock_hop_bal['genre_top']
pca_projection = pca.fit_transform(scaler.fit_transform(features))

# Redefine the train and test set with the pca_projection from the balanced data
train_features, test_features, train_labels, test_labels = train_test_split( pca_projection , labels, random_state=18)

# %% [markdown]
# ## Does balancing our dataset improve model bias?

# %%
# Train our decision tree on the balanced data
tree = DecisionTreeClassifier(random_state=18)
tree.fit(train_features, train_labels)
pred_labels_tree = tree.predict(test_features)

# Train our logistic regression on the balanced data
logreg = LogisticRegression(random_state = 18)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Compare the models
print("Decision Tree: \n", classification_report(test_labels, pred_labels_tree))
print("Logistic Regression: \n", classification_report(test_labels, pred_labels_logit))
# Out:
# Decision Tree:
#               precision    recall  f1-score   support
#
#     Hip-Hop       0.80      0.83      0.81       230
#        Rock       0.82      0.79      0.80       225
#
# avg / total       0.81      0.81      0.81       455
#
# Logistic Regression:
#               precision    recall  f1-score   support
#
#     Hip-Hop       0.84      0.83      0.84       230
#        Rock       0.83      0.84      0.83       225
#
# avg / total       0.84      0.84      0.84       455

# %% [markdown]
# ## Using cross-validation to evaluate our models

# %%
from sklearn.model_selection import KFold, cross_val_score

# Set up our K-fold cross-validation
kf = KFold(n_splits=10, random_state = 18)

tree = DecisionTreeClassifier(random_state=18)
logreg = LogisticRegression(random_state=18)

# Train our models using KFold cv
tree_score = cross_val_score(tree, pca_projection, labels, cv=kf)
logit_score = cross_val_score(logreg, pca_projection, labels, cv=kf)

# Print the mean of each array of scores
print("Decision Tree:", np.mean(tree_score) ,"Logistic Regression:", np.mean(logit_score))
# Out:
# Decision Tree: 0.7719780219780219 Logistic Regression: 0.7901098901098901
